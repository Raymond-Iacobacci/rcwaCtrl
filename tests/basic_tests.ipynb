# %%
# %load_ext autoreload
# %autoreload 2
import sys
import os
sys.path.append(os.path.abspath(".."))
import solver
import pandas as pd
import numpy as np

n_all = pd.read_excel("/Users/raymondiacobacci/LeiteLab-6_8/n-allHTMats-2.xlsx")
k_all = pd.read_excel("/Users/raymondiacobacci/LeiteLab-6_8/k-allHTMats.xlsx")

test_wavelength_index = 650

n_harmonics = 0

er = np.ones(shape = (100,))
# er[50] += 1
ur = np.ones(shape = (100,))
air_layer = solver.Layer(permittivity = np.ones(shape = (100,)), permeability = np.ones(shape = (100,)), thickness = 9, n_harmonics = n_harmonics)
aln_grating = solver.Layer(
    # permittivity=1*er,
    permittivity=er*2,
    permeability=ur,
    thickness=.473,
    n_harmonics=n_harmonics,
)
my_solver = solver.Solver(layer_stack = [air_layer, aln_grating, air_layer], grating_period = 1, wavelength = 1, n_harmonics = n_harmonics)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [[ 0.+0.j  2.+0.j]
#  [-2.+0.j  0.+0.j]]
# [0.+1.414214j 0.+1.414214j]
# Backward lambda:
# [-0.-1.414214j -0.-1.414214j]
# Forward lambda:
# [0.+1.414214j 0.+1.414214j]
# Layer transfer matrix:
# [[ 1.      +0.j  0.      +0.j  1.      +0.j  0.      +0.j]
#  [ 0.      +0.j  1.      +0.j  0.      +0.j  1.      +0.j]
#  [ 0.      +0.j -1.414214+0.j  0.      +0.j  1.414214+0.j]
#  [ 1.414214+0.j  0.      +0.j -1.414214+0.j  0.      +0.j]]
# Vacuum transfer matrix
# [[ 1.+0.j  0.+0.j  1.+0.j  0.+0.j]
#  [ 0.+0.j  1.+0.j  0.+0.j  1.+0.j]
#  [ 0.+0.j -1.+0.j  0.+0.j  1.+0.j]
#  [ 1.+0.j  0.+0.j -1.+0.j  0.+0.j]]
# M1:
# [[0.853553+0.j 0.      +0.j 0.146447+0.j 0.      +0.j]
#  [0.      +0.j 0.853553+0.j 0.      +0.j 0.146447+0.j]
#  [0.146447+0.j 0.      +0.j 0.853553+0.j 0.      +0.j]
#  [0.      +0.j 0.146447+0.j 0.      +0.j 0.853553+0.j]]
# First interface reflection:
# (-0.17157287525380988+0j)
# First interface propagation:
# (0.8284271247461901+0j)
# total
# (0.715728752538099+0j) (1+0j)
# Forward propagation matrix
# [[-0.487672+0.873027j  0.      +0.j      ]
#  [ 0.      +0.j       -0.487672+0.873027j]]
# Backward propagation matrix
# [[-0.487672+0.873027j  0.      +0.j      ]
#  [ 0.      +0.j       -0.487672+0.873027j]]
# Second interface propagation:
# (-0.5713438441470315+1.022814359395571j)
# (-0.26412071888108063-1.0508130410341994j)
# (0.5321899205346091-0.38887182599506315j)
# (-1.8811555920664078+0.4728264190695121j)
# (-0.6961546740490826-0.952721374745933j)
# (-0.5321899205346091+0.38887182599506315j)
# (0.26412071888108063+1.0508130410341994j)
# (0.6961546740490826+0.952721374745933j)
# (1.8811555920664078-0.4728264190695121j)
# [[-0.487672+0.873027j  0.      +0.j       -0.487672+0.873027j  0.      +0.j      ]
#  [ 0.      +0.j       -0.487672+0.873027j  0.      +0.j       -0.487672+0.873027j]
#  [ 0.      +0.j        0.689673-1.234646j  0.      +0.j       -0.689673+1.234646j]
#  [-0.689673+1.234646j  0.      +0.j        0.689673-1.234646j  0.      +0.j      ]]
# [[ 1.+0.j  0.+0.j  1.+0.j  0.+0.j]
#  [ 0.+0.j  1.+0.j  0.+0.j  1.+0.j]
#  [ 0.-0.j  1.-0.j  0.-0.j -1.+0.j]
#  [-1.+0.j  0.-0.j  1.-0.j  0.-0.j]]
# Second half transfer matrix:
# [[0.207107 0.       1.207107 0.      ]
#  [0.       0.207107 0.       1.207107]
#  [1.207107 0.       0.207107 0.      ]
#  [0.       1.207107 0.       0.207107]]
# [[ 0.101   -0.18081j   0.      +0.j       -0.588673+1.053836j  0.      +0.j      ]
#  [ 0.      +0.j        0.101   -0.18081j   0.      +0.j       -0.588673+1.053836j]
#  [-0.588673+1.053836j  0.      +0.j        0.101   -0.18081j   0.      +0.j      ]
#  [ 0.      +0.j       -0.588673+1.053836j  0.      +0.j        0.101   -0.18081j ]]
# Final transfer matrix:
# [[-0.      +0.j        0.      +0.j       -0.487672+0.873027j  0.      +0.j      ]
#  [ 0.      +0.j       -0.      +0.j        0.      +0.j       -0.487672+0.873027j]
#  [-0.487672+0.873027j  0.      +0.j       -0.      +0.j        0.      +0.j      ]
#  [ 0.      +0.j       -0.487672+0.873027j  0.      +0.j       -0.      +0.j      ]]
# [[0.853553+0.j 0.      +0.j 0.146447+0.j 0.      +0.j]
#  [0.      +0.j 0.853553+0.j 0.      +0.j 0.146447+0.j]
#  [0.146447+0.j 0.      +0.j 0.853553+0.j 0.      +0.j]
#  [0.      +0.j 0.146447+0.j 0.      +0.j 0.853553+0.j]]

# %%
a=(-1+np.sqrt(2))/2
print(a)
2*np.sqrt(2)/(1+np.sqrt(2))
2/(np.sqrt(2)+1)
((np.sqrt(2)-1)/(np.sqrt(2)+1))**2
# Out:
# 0.20710678118654757
# np.float64(0.029437251522859434)

# %%
2/(np.sqrt(2)+1)
# Out:
# np.float64(0.8284271247461902)

# %%
a=0.101+0.18081j
b=-0.588673-1.053836j
c=0.588673-1.053836j
d=0.101+0.18081j
a-b*c/d
# Out:
# (3.5320225238024077-5.961399728007062j)
