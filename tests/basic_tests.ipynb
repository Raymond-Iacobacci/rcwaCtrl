# %%
# %load_ext autoreload
# %autoreload 2
import sys
import os
sys.path.append(os.path.abspath(".."))
import solver
import pandas as pd
import numpy as np

n_all = pd.read_excel("/Users/raymondiacobacci/LeiteLab-6_8/n-allHTMats-2.xlsx")
k_all = pd.read_excel("/Users/raymondiacobacci/LeiteLab-6_8/k-allHTMats.xlsx")

test_wavelength_index = 650

n_harmonics = 0

er = np.ones(shape = (100,))
er[50] += 1
ur = np.ones(shape = (100,))
air_layer = solver.Layer(permittivity = np.ones(shape = (100,)), permeability = np.ones(shape = (100,)), thickness = 9, n_harmonics = n_harmonics)
aln_grating = solver.Layer(
    # permittivity=1*er,
    permittivity=er*2,
    permeability=ur,
    thickness=.473,
    n_harmonics=n_harmonics,
)
my_solver = solver.Solver(layer_stack = [air_layer, aln_grating, air_layer], grating_period = 1, wavelength = 1, n_harmonics = n_harmonics)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Vacuum transfer matrix:
#           0         1         2         3
# 0  1.0+0.0j  0.0+0.0j  1.0+0.0j  0.0+0.0j
# 1  0.0+0.0j  1.0+0.0j  0.0+0.0j  1.0+0.0j
# 2  0.0-0.0j  1.0-0.0j  0.0-0.0j -1.0+0.0j
# 3 -1.0+0.0j  0.0-0.0j  1.0-0.0j  0.0-0.0j
# Inverse vacuum:
#           0         1         2         3
# 0  1.0+0.0j  0.0+0.0j  1.0+0.0j  0.0+0.0j
# 1  0.0+0.0j  1.0+0.0j  0.0+0.0j  1.0+0.0j
# 2  0.0+0.0j -1.0+0.0j  0.0+0.0j  1.0+0.0j
# 3  1.0+0.0j  0.0+0.0j -1.0+0.0j  0.0+0.0j
# [[ 0.+0.j  1.+0.j]
#  [-1.+0.j  0.+0.j]] [[ 0.  +0.j  2.02+0.j]
#  [-2.02+0.j  0.  +0.j]]
# [[1.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j]]
# Lambda results (propagation):
# [0.+1.421267j 0.+1.421267j]
# M1:
# [[0.851799+0.j 0.      +0.j 0.148201+0.j 0.      +0.j]
#  [0.      +0.j 0.851799+0.j 0.      +0.j 0.148201+0.j]
#  [0.148201+0.j 0.      +0.j 0.851799+0.j 0.      +0.j]
#  [0.      +0.j 0.148201+0.j 0.      +0.j 0.851799+0.j]]
# [[ 1.+0.j  0.+0.j  1.+0.j  0.+0.j]
#  [ 0.+0.j  1.+0.j  0.+0.j  1.+0.j]
#  [ 0.-0.j  1.-0.j  0.-0.j -1.+0.j]
#  [-1.+0.j  0.-0.j  1.-0.j  0.-0.j]]
# [[ 1.      +0.j  0.      +0.j  1.      +0.j  0.      +0.j]
#  [ 0.      +0.j  1.      +0.j  0.      +0.j  1.      +0.j]
#  [ 0.      -0.j  1.421267-0.j  0.      -0.j -1.421267+0.j]
#  [-1.421267+0.j  0.      -0.j  1.421267-0.j  0.      -0.j]]
# [[-0.469266+0.883057j  0.      +0.j       -0.469266+0.883057j  0.      +0.j      ]
#  [ 0.      +0.j       -0.469266+0.883057j  0.      +0.j       -0.469266+0.883057j]
#  [ 0.      +0.j       -0.666952+1.25506j   0.      +0.j        0.666952-1.25506j ]
#  [ 0.666952-1.25506j   0.      +0.j       -0.666952+1.25506j   0.      +0.j      ]]
# [[ 0.5+0.j  0. +0.j  0. +0.j  0.5+0.j]
#  [ 0. +0.j  0.5+0.j -0.5+0.j  0. +0.j]
#  [ 0.5-0.j -0. -0.j -0. -0.j -0.5-0.j]
#  [ 0. +0.j  0.5+0.j  0.5+0.j  0. +0.j]]
# Second half transfer matrix:
# [[ 0.098843-0.186001j  0.      +0.j       -0.568109+1.069058j  0.      +0.j      ]
#  [ 0.      +0.j        0.098843-0.186001j  0.      +0.j       -0.568109+1.069058j]
#  [-0.568109+1.069058j  0.      +0.j        0.098843-0.186001j  0.      +0.j      ]
#  [ 0.      +0.j       -0.568109+1.069058j  0.      +0.j        0.098843-0.186001j]]
# Final transfer matrix:
# [[-0.      -0.j        0.      +0.j       -0.469266+0.883057j  0.      +0.j      ]
#  [ 0.      +0.j       -0.      -0.j        0.      +0.j       -0.469266+0.883057j]
#  [-0.469266+0.883057j  0.      +0.j       -0.      -0.j        0.      +0.j      ]
#  [ 0.      +0.j       -0.469266+0.883057j  0.      +0.j       -0.      -0.j      ]]
# [[0.851799+0.j 0.      +0.j 0.148201+0.j 0.      +0.j]
#  [0.      +0.j 0.851799+0.j 0.      +0.j 0.148201+0.j]
#  [0.148201+0.j 0.      +0.j 0.851799+0.j 0.      +0.j]
#  [0.      +0.j 0.148201+0.j 0.      +0.j 0.851799+0.j]]
